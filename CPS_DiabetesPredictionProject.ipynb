# %%
# Import Libraries and Load Dataset
import pandas as pd

file_path = '/content/diabetes_012_health_indicators_BRFSS2021.csv'
df = pd.read_csv(file_path)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236378 entries, 0 to 236377
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          236378 non-null  float64
#  1   HighBP                236378 non-null  int64
#  2   HighChol              236378 non-null  float64
#  3   CholCheck             236378 non-null  int64
#  4   BMI                   236378 non-null  float64
#  5   Smoker                236378 non-null  float64
#  6   Stroke                236378 non-null  float64
#  7   HeartDiseaseorAttack  236378 non-null  float64
#  8   PhysActivity          236378 non-null  int64
#  9   Fruits                236378 non-null  int64
#  10  Veggies               236378 non-null  int64
#  11  HvyAlcoholConsump     236378 non-null  int64
#  12  AnyHealthcare         236378 non-null  int64
#  13  NoDocbcCost           236378 non-null  float64
# ...

# %%
duplicate_rows = df[df.duplicated()]

# %%
if not duplicate_rows.empty:
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
#         Diabetes_012  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 1245             0.0       0       0.0          1  27.0     1.0     0.0
# 2596             0.0       0       0.0          1  29.0     0.0     0.0
# 3895             0.0       0       0.0          1  28.0     0.0     0.0
# 3937             0.0       0       0.0          1  22.0     0.0     0.0
# 4018             0.0       0       0.0          1  26.0     0.0     0.0
# ...              ...     ...       ...        ...   ...     ...     ...
# 236322           0.0       0       0.0          1  25.0     0.0     0.0
# 236323           0.0       1       0.0          1  31.0     0.0     0.0
# 236327           0.0       0       0.0          1  25.0     0.0     0.0
# 236354           0.0       1       0.0          1  25.0     1.0     0.0
# 236358           0.0       0       0.0          1  28.0     1.0     0.0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# ...

# %%
df_no_duplicates = df.drop_duplicates()
print("\nDataFrame without Duplicates:")
print(df_no_duplicates.info())
print(df_no_duplicates.head())
# Out:
# DataFrame without Duplicates:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223550 entries, 0 to 236377
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          223550 non-null  float64
#  1   HighBP                223550 non-null  int64
#  2   HighChol              223550 non-null  float64
#  3   CholCheck             223550 non-null  int64
#  4   BMI                   223550 non-null  float64
#  5   Smoker                223550 non-null  float64
#  6   Stroke                223550 non-null  float64
#  7   HeartDiseaseorAttack  223550 non-null  float64
#  8   PhysActivity          223550 non-null  int64
#  9   Fruits                223550 non-null  int64
#  10  Veggies               223550 non-null  int64
#  11  HvyAlcoholConsump     223550 non-null  int64
#  12  AnyHealthcare         223550 non-null  int64
#  13  NoDocbcCost           223550 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

print("\nMissing Values in Each Column:")
print(df.isnull().sum())

print("\nStatistical Summary of the Dataset:")
print(df.describe())
# Out:
# Missing Values in Each Column:
# Diabetes_012            0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64
#
# Statistical Summary of the Dataset:
#         Diabetes_012         HighBP       HighChol      CholCheck  \
# count  236378.000000  236378.000000  236378.000000  236378.000000
# mean        0.307791       0.418558       0.402059       0.963347
# std         0.705037       0.493324       0.490315       0.187909
# ...

# %%
sns.countplot(x='Diabetes_012', data = df)
plt.title('Distribution of Target Variable (Diabetes_012)')
plt.show()

# %%
df.corr()
# Out:
#                       Diabetes_012    HighBP  HighChol  CholCheck       BMI  \
# Diabetes_012              1.000000  0.269086  0.207435   0.072222  0.211801
# HighBP                    0.269086  1.000000  0.283285   0.099415  0.213951
# HighChol                  0.207435  0.283285  1.000000   0.098558  0.087188
# CholCheck                 0.072222  0.099415  0.098558   1.000000  0.036226
# BMI                       0.211801  0.213951  0.087188   0.036226  1.000000
# Smoker                    0.058910  0.099570  0.082402  -0.012874  0.016289
# Stroke                    0.102715  0.126594  0.085947   0.025386  0.010241
# HeartDiseaseorAttack      0.177432  0.203191  0.170668   0.043867  0.039518
# PhysActivity             -0.151657 -0.132253 -0.076648  -0.008454 -0.163979
# Fruits                   -0.030489 -0.031542 -0.024408   0.024951 -0.089897
# Veggies                  -0.047853 -0.036013 -0.031931   0.017397 -0.047900
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=False, cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Diabetes_012', y='BMI', data=df)
plt.title('BMI Distribution by Diabetes Status')
plt.xlabel('Diabetes Status (0=No, 1=Pre-Diabetes, 2=Diabetes)')
plt.ylabel('BMI')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='CholCheck', hue='Diabetes_012', data=df)
plt.title('Cholesterol Check vs Diabetes Status')
plt.xlabel('Cholesterol Check (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='PhysActivity', hue='Diabetes_012', data=df)
plt.title('Physical Activity vs Diabetes Status')
plt.xlabel('Physical Activity (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x='Diabetes_012', y='Age', data=df)
plt.title('Age Distribution by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Smoker', hue='Diabetes_012', data=df)
plt.title('Smoking Habits vs Diabetes Status')
plt.xlabel('Smoker (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Diabetes_012', y='GenHlth', data=df)
plt.title('General Health Rating by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('General Health Rating (1=Excellent, 5=Poor)')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Diabetes_012', y='Income', data=df)
plt.title('Income Distribution by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('Income Level')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='HvyAlcoholConsump', hue='Diabetes_012', data=df)
plt.title('Heavy Alcohol Consumption vs Diabetes Status')
plt.xlabel('Heavy Alcohol Consumption (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Sex', hue='Diabetes_012', data=df)
plt.title('Sex vs Diabetes Status')
plt.xlabel('Sex (0=Female, 1=Male)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Diabetes_012', y='MentHlth', data=df)
plt.title('Mental Health (Days of Poor Mental Health) by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('Days of Poor Mental Health')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x='Diabetes_012', y='PhysHlth', data=df)
plt.title('Physical Health (Days of Poor Physical Health) by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('Days of Poor Physical Health')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='DiffWalk', hue='Diabetes_012', data=df)
plt.title('Difficulty Walking vs Diabetes Status')
plt.xlabel('Difficulty Walking (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='AnyHealthcare', hue='Diabetes_012', data=df)
plt.title('Access to Healthcare vs Diabetes Status')
plt.xlabel('Access to Healthcare (0=No, 1=Yes)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='PhysActivity', y='HighChol', hue='Diabetes_012', data=df)
plt.title('Cholesterol Level vs Physical Activity')
plt.xlabel('Physical Activity (0=No, 1=Yes)')
plt.ylabel('High Cholesterol Level')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Education', hue='Diabetes_012', data=df)
plt.title('Education Level vs Diabetes Status')
plt.xlabel('Education Level (1=Less than High School, 6=Graduate School)')
plt.ylabel('Count')
plt.legend(title='Diabetes Status', loc='upper right')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical variable (if `Sex` is present)
if 'Sex' in df.columns:
    label_encoder = LabelEncoder()
    df['Sex'] = label_encoder.fit_transform(df['Sex'])

# Example: Group age into categories (optional, based on dataset)
age_bins = [0, 18, 35, 50, 65, 100]
age_labels = ['Child', 'Young Adult', 'Adult', 'Middle Age', 'Senior']
df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

print(df.head())
# Out:
#    Diabetes_012  HighBP  HighChol  CholCheck   BMI  Smoker  Stroke  \
# 0           0.0       0       1.0          1  15.0     1.0     0.0
# 1           2.0       1       0.0          1  28.0     0.0     0.0
# 2           2.0       1       1.0          1  33.0     0.0     0.0
# 3           2.0       0       1.0          1  29.0     0.0     1.0
# 4           0.0       0       0.0          1  24.0     1.0     0.0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  NoDocbcCost  GenHlth  \
# 0                   0.0             0       1  ...          0.0      5.0
# 1                   1.0             0       1  ...          0.0      2.0
# 2                   0.0             1       1  ...          0.0      2.0
# 3                   1.0             1       1  ...          0.0      5.0
# 4                   0.0             0       0  ...          0.0      3.0
#
#    MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  Income  Age_Group
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select numeric columns for scaling
numeric_features = ['BMI', 'Age', 'MentHlth', 'PhysHlth']  # Example columns
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

print(df[numeric_features].head())
# Out:
#         BMI       Age  MentHlth  PhysHlth
# 0 -2.129654  0.968823  0.768693  1.970522
# 1 -0.145539  0.968823 -0.499298 -0.454929
# 2  0.617582  0.350965  0.768693 -0.454929
# 3  0.007085  1.277752 -0.499298  3.183247
# 4 -0.756036  1.586681 -0.499298 -0.454929

# %%
# Detect outliers using IQR
for col in numeric_features:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

print(df[numeric_features].describe())
# Out:
#                  BMI           Age       MentHlth       PhysHlth
# count  236378.000000  2.363780e+05  236378.000000  236378.000000
# mean       -0.025699 -3.318579e-17      -0.202962      -0.300863
# std         0.911905  1.000002e+00       0.470577       0.242164
# min        -2.587526 -2.120467e+00      -0.499298      -0.454929
# 25%        -0.756036 -8.847509e-01      -0.499298      -0.454929
# 50%        -0.145539  4.203602e-02      -0.499298      -0.454929
# 75%         0.464958  6.598940e-01       0.007898      -0.212384
# max         2.296448  1.586681e+00       0.768693       0.151433

# %%
# Exclude non-numeric columns from correlation matrix calculation
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

# Select correlated features based on threshold
correlated_features = correlation_matrix['Diabetes_012'].abs().sort_values(ascending=False)
selected_features = correlated_features[correlated_features > 0.1].index.tolist()
selected_features.remove('Diabetes_012')  # Exclude target column

print("Selected Features:", selected_features)
# Out:
# Selected Features: ['GenHlth', 'HighBP', 'DiffWalk', 'BMI', 'HighChol', 'Age', 'HeartDiseaseorAttack', 'Income', 'PhysActivity', 'PhysHlth', 'Education', 'Stroke']

# %%
# Split data into X (features) and y (target)
X = df[selected_features]
y = df['Diabetes_012']

print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (236378, 12)
# Target Shape: (236378,)

# %%
# Save processed data to CSV
X.to_csv('processed_features.csv', index=False)
y.to_csv('processed_target.csv', index=False)

# %%
def preprocess_data(df):
    # Feature Engineering
    if 'Sex' in df.columns:
        df['Sex'] = LabelEncoder().fit_transform(df['Sex'])

    # Encode Age_Group to numeric if it exists
    if 'Age_Group' in df.columns:
        df['Age_Group'] = LabelEncoder().fit_transform(df['Age_Group'].astype(str))

    # Handle missing values: Fill with median (numeric) or mode (categorical)
    for col in df.select_dtypes(include='number').columns:
        if df[col].isnull().sum() > 0:
            df[col] = df[col].fillna(df[col].median())



    # Scale numeric features
    numeric_features = ['BMI', 'Age', 'MentHlth', 'PhysHlth']  # Add other numeric columns as needed
    scaler = StandardScaler()
    df[numeric_features] = scaler.fit_transform(df[numeric_features])

    # Handle outliers
    for col in numeric_features:
        Q1, Q3 = df[col].quantile(0.25), df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound, upper_bound = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
        df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)

    # Select features
    correlation_matrix = df.corr()
    correlated_features = correlation_matrix['Diabetes_012'].abs().sort_values(ascending=False)
    selected_features = correlated_features[correlated_features > 0.1].index.tolist()
    selected_features.remove('Diabetes_012')  # Exclude target column

    X = df[selected_features]
    y = df['Diabetes_012']

    # Final check for missing values in X
    if X.isnull().sum().any():
        print("Filling remaining missing values in features...")
        X.fillna(X.median(), inplace=True)

    return X, y

# %%
from graphviz import Digraph

# Visualize pipeline
dot = Digraph()

dot.node("Load", "Load Dataset")
dot.node("Preprocess", "Preprocess Data")
dot.node("Feature Engg", "Feature Engineering")
dot.node("Outliers", "Handle Outliers")
dot.node("Scaling", "Normalize/Scale")
dot.node("Select", "Feature Selection")
dot.node("Save", "Save Data")
dot.node("Model", "Train Model")

# Add edges between nodes
dot.edge("Load", "Preprocess")
dot.edge("Preprocess", "Feature Engg")
dot.edge("Feature Engg", "Outliers")
dot.edge("Outliers", "Scaling")
dot.edge("Scaling", "Select")
dot.edge("Select", "Save")
dot.edge("Save", "Model")

# Render the graph to a file (you can also visualize it inline)
dot.render("pipeline", format="png", cleanup=True)
# Out:
# 'pipeline.png'

# %%
from pyngrok import ngrok

# Paste your token here (replace with your actual token)
# !ngrok config add-authtoken 35MM2pd3ZyrCx8YLugqkXVtrFdz_2WdA3xQBFdB8AQigyfPpW
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install streamlit pyngrok scikit-learn pandas numpy matplotlib

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

st.title("🩺 Diabetes Prediction App")
st.write("Enter patient details below to predict whether the person has diabetes or not.")

# Load and train model (Pima Indians dataset)
@st.cache_data
def load_model():
    data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv")
    X = data.drop("Outcome", axis=1)
    y = data["Outcome"]

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    model = LogisticRegression()
    model.fit(X_scaled, y)
    return model, scaler

model, scaler = load_model()

# Input fields
st.subheader("Enter Patient Data:")

Pregnancies = st.number_input("Pregnancies", min_value=0, max_value=20, value=2)
Glucose = st.number_input("Glucose Level", min_value=0.0, max_value=300.0, value=120.0)
BloodPressure = st.number_input("Blood Pressure", min_value=0.0, max_value=200.0, value=70.0)
SkinThickness = st.number_input("Skin Thickness", min_value=0.0, max_value=100.0, value=20.0)
Insulin = st.number_input("Insulin Level", min_value=0.0, max_value=900.0, value=80.0)
BMI = st.number_input("BMI", min_value=0.0, max_value=70.0, value=25.0)
DiabetesPedigreeFunction = st.number_input("Diabetes Pedigree Function", min_value=0.0, max_value=3.0, value=0.5)
Age = st.number_input("Age", min_value=1, max_value=120, value=30)

# Prediction
if st.button("🔍 Predict"):
    input_data = np.array([[Pregnancies, Glucose, BloodPressure, SkinThickness,
                            Insulin, BMI, DiabetesPedigreeFunction, Age]])
    input_scaled = scaler.transform(input_data)
    prediction = model.predict(input_scaled)[0]

    st.subheader("Prediction Result:")
    if prediction == 1:
        st.error("🔴 The person is likely to have diabetes.")
    else:
        st.success("🟢 The person is not likely to have diabetes.")
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok
# !streamlit run app.py &>/content/logs.txt &
public_url = ngrok.connect(8501)
print("Open this link to use the app:", public_url)
# Out:
# Open this link to use the app: NgrokTunnel: "https://seismologic-damien-nontransparently.ngrok-free.dev" -> "http://localhost:8501"
